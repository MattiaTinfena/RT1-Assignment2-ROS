# %% [markdown]
# # Assignment 2 Research track 2
#
# This notebook is an interface for the second assignment of Research Track 1 that substitute the actionClientNode.py.
#
# The functions of this notebook are implemented to:
# - Implement a GUI with some widgets and buttons to interact with the robot
# - Show the position and the speed of the robot
# - Show the path made by the robot in the graph
# - Show a bar graph with the reached and not reached goals

# %%
#!/usr/bin/env python

import rospy
import actionlib
import actionlib.msg
import sys
import threading 

from geometry_msgs.msg import PoseStamped
from nav_msgs.msg import Odometry
from assignment_2_2024.msg import PlanningAction, PlanningGoal
from assignment2_ros1.msg import RobotInfo
from sensor_msgs.msg import LaserScan

import ipywidgets as widgets
from IPython.display import display
import os
import platform

# %matplotlib widget

import matplotlib.pyplot as plt 
import tf

from tf.transformations import quaternion_matrix 
import numpy as np
from matplotlib.animation import FuncAnimation

import time
from ipywidgets import Button, Layout, ButtonStyle, GridBox, VBox, HBox

# %% [markdown]
# ## Global variables

# %%
feedbackData = None 

distanceFromObstacle = 0.0

robotStatus = RobotInfo()
distanceWid = widgets.Label()
odomWid = widgets.Label()

hist_label = ["Reached", "Not reached"]

goal = None
active_goal = False
reached_goals = 0
not_reached_goals = 0
test = False

# %% [markdown]
# ## ROS interaction functions
#
# These are the functions used both by the subscribers as callbacks to read from a topic and by the publisher to public messages

# %%
def feedbackHandler(feedback):
    """Callback to handle feedback from the action server."""
    global feedbackData, goal, active_goal, not_reached_goals, reached_goals, test
    feedbackData = feedback

    if (active_goal and "reached" in feedbackData.stat):
        reached_goals = reached_goals + 1
        active_goal = False
        goal = None

def sendGoal(client, xTarget, yTarget):
    """Sends a goal to the action server."""
    
    global goal, active_goal, not_reached_goals

    goal = PlanningGoal()
    goal.target_pose = PoseStamped()
    goal.target_pose.pose.position.x = xTarget
    goal.target_pose.pose.position.y = yTarget
    
    if active_goal:
        not_reached_goals = not_reached_goals + 1
    else:
        active_goal = True
        
    client.send_goal(goal, feedback_cb=feedbackHandler)
    rospy.loginfo("Goal has been sent to the action server.")

def publishStatus(odomMsg):
    """Publishes the robot's current position and velocity."""
    global robotStatus 
    global xdata
    global ydata
    
    robotStatus.x = odomMsg.pose.pose.position.x
    robotStatus.y = odomMsg.pose.pose.position.y
    robotStatus.velX = odomMsg.twist.twist.linear.x
    robotStatus.velZ = odomMsg.twist.twist.angular.z
    
    ydata.append(odomMsg.pose.pose.position.y)
    xdata.append(odomMsg.pose.pose.position.x)
    
    statusPublisher.publish(robotStatus)
    
def obstDist(laserMsg):
    global distanceFromObstacle
    distanceFromObstacle = min(min(laserMsg.ranges), 10)

# %% [markdown]
# ## Buttons callbacks
#
# These functions are the callbacks for the buttons widgets

# %%
def sendTarget(b,xTarget,yTarget, client):
    print(f"Targets:{xTarget},{yTarget}")
    
    # Initialize the action client and wait for the server
    
    client.wait_for_server()
    sendGoal(client, xTarget, yTarget)
    
def quitBtnClick(b,client):
    
    global not_reached_goals, active_goal
    
    if client.get_state() not in [actionlib.GoalStatus.SUCCEEDED, actionlib.GoalStatus.ABORTED, actionlib.GoalStatus.PREEMPTED]:
        rospy.loginfo("Cancelling the current goal.")
        client.cancel_goal()
        not_reached_goals = not_reached_goals + 1
        active_goal = False
    else:
        rospy.loginfo("The goal has already been achieved.")
def feedbackBtnClick(b):
    rospy.loginfo("Requesting feedback...")
    if feedbackData is None:
        rospy.loginfo("No feedback received yet.")
    else:
        rospy.loginfo("Latest feedback: %s", feedbackData)
        
def exitBtnClick(b,client):
    
    global not_reached_goals
    
    if client.get_state() not in [actionlib.GoalStatus.SUCCEEDED, actionlib.GoalStatus.ABORTED, actionlib.GoalStatus.PREEMPTED]:
        rospy.loginfo("Cancelling goal and shutting down.")
        client.cancel_goal()
        
        not_reached_goals = not_reached_goals + 1
        goal = None
        active_goal = False
    else:
        rospy.loginfo("Shutting down.")

# %% [markdown]
# ## Threads functions
#
# These functions are used from the threads to spin the node and update the values on the GUI

# %%
def updateValues():    
    while not rospy.is_shutdown():
        distanceWid.value = f"Distance from the closest obstacle: {distanceFromObstacle:.2f} m"
        pos = f"Position: x: {robotStatus.x:.2f}, y: {robotStatus.y:.2f}"
        vel = f"Velocity: lin {robotStatus.velX:.2f}, ang {robotStatus.velZ:.2f}"
        odomWid.value = f"{pos} {vel}"
        
        time.sleep(0.5)

# %%
def spinThread():
    rospy.spin()

# %% [markdown]
# ## Functions for the plots
# This functions are used to initialize and update the plots

# %%
def plot_init():
    ax.set_title("Robot's Path")
    ax.set_xlim(-10, 10)
    ax.set_ylim(-10, 10)
    return ln,

def plot_update(frame):
    ln.set_data(xdata, ydata)
    return ln,

def goal_plot_init():
    global hist_label
    axHist.set_ylim(0, 10) 
    return []

def goal_plot_update(frame):
    axHist.clear()
    axHist.set_ylim(0, 10)
    axHist.set_title("Goals stats")
    bar_container = axHist.bar(hist_label, [reached_goals, not_reached_goals], color=['green', 'red'])
    return bar_container.patches

# %%
if __name__ == '__main__':
    try:
        rospy.init_node("robotActionClient")
        
        #subscribers
        
        statusPublisher = rospy.Publisher("/robot_status", RobotInfo, queue_size=10)
        rospy.Subscriber("/odom", Odometry, publishStatus)
        rospy.Subscriber("/scan",LaserScan, obstDist)
        
        #Variables for the plots

        xdata, ydata = [], []
                    
        fig, (ax, axHist) = plt.subplots(1, 2, figsize=(10, 5))
        ln, = ax.plot([], [], 'ro')
                
        #Setup the thread to update the values
        
        t = threading.Thread(target=updateValues)
        t.daemon = True
        t.start()
        
        #Setup the thread for the spin
        
        ts = threading.Thread(target=spinThread)
        ts.daemon = True
        ts.start()

        #Connect to the action server
        actionClient = actionlib.SimpleActionClient('reaching_goal', PlanningAction)
        
        #Define the widgets
        print("Set the xTargets and the yTarget and then press the start button to set the goal")
        xCoordWid = widgets.FloatText(value=6,description='xTarget:',disabled=False)
        yCoordWid = widgets.FloatText(value=6,description='yTarget:',disabled=False)
        
        startBtn = widgets.Button(description = "Start")
        startBtn.style.button_color = 'lightgreen'
        
        def startBtnClick(b):
            if xCoordWid.value > 10:
                xTarget = 10
            elif xCoordWid.value < -10:
                xTarget = -10
            else:
                xTarget = xCoordWid.value
            
            if yCoordWid.value > 10:
                yTarget = 10
            elif yCoordWid.value < -10:
                yTarget = -10
            else:
                yTarget = yCoordWid.value
            
            sendTarget(b, xTarget, yTarget, actionClient)

        startBtn.on_click(startBtnClick)
        
        quitBtn = Button(description='Quit',
        layout=Layout(width='auto', align="center",
        grid_area='quitBtn'),
        style=ButtonStyle(button_color='salmon'))
        feedbackBtn = Button(description='Feedback',
        layout=Layout(width='auto', grid_area='feedbackBtn'),
        style=ButtonStyle(button_color='moccasin'))
        exitBtn = Button(description='Exit',
        layout=Layout(width='auto', grid_area='exitBtn'),
        style=ButtonStyle(button_color='lightblue'))
        
        hButBox = HBox([quitBtn,feedbackBtn,exitBtn])
        selectionBox = VBox([xCoordWid, yCoordWid])
        buttonsBox = VBox([startBtn, hButBox])
        
        finalBox= VBox([selectionBox, buttonsBox, distanceWid, odomWid])
        display(finalBox)
        
        def stopBtnClick(b):
            quitBtnClick(b, actionClient)
            
        def exitButton(b):
            exitBtnClick(b, actionClient)

        quitBtn.on_click(stopBtnClick)
        feedbackBtn.on_click(feedbackBtnClick)
        exitBtn.on_click(exitButton)
        
        # matplotlib graphs
       
        ani = FuncAnimation(fig, plot_update, init_func=plot_init)
        ani2 = FuncAnimation(fig, goal_plot_update, init_func=goal_plot_init, blit=False)
        plt.show()
        
    except rospy.ROSInterruptException:
        rospy.logerr("Action client was interrupted.")
        sys.exit(1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Set the xTargets and the yTarget and then press the start button to set the goal
# VBox(children=(VBox(children=(FloatText(value=6.0, description='xTarget:'), FloatText(value=6.0, description='…
# Targets:6.0,6.0
# [INFO] [1746613857.578122, 6055.371000]: Goal has been sent to the action server.
# [INFO] [1746613910.617587, 6107.538000]: Cancelling the current goal.
# Targets:3.0,5.0
# [INFO] [1746613932.026017, 6128.609000]: Goal has been sent to the action server.
